# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, regularizers

import numpy as np

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, regularizers

import numpy as np

X_files = [
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_1.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_2.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_3.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_4.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_5.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_6.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_7.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_8.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_9.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_10.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_11.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_12.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_13.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_14.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_15.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_16.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_17.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_18.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_19.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_20.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_21.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_22.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_23.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_24.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_25.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_26.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_27.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_28.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_29.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_30.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_31.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_32.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_33.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_34.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_35.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_36.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_37.npy"
]



# X_files = [
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_1.npy",
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_2.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_3.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_4.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_5.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_6.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_7.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_X_8.npy", # Fixed path here
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_9.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_10.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_11.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_12.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_13.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_14.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_15.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_16.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_17.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_18.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_19.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_20.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_21.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_22.npy",
#   #   "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_23.npy",
#   #  "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_X_24.npy",
# ]

Y_files = [
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_1.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_2.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_3.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_4.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_5.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_6.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_7.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_8.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_9.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_10.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_11.npy",
    "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_12.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_13.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_14.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_15.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_16.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_17.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_18.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_19.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_20.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_21.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_22.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_23.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_24.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_25.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_26.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_27.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_28.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_29.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_30.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_31.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_32.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_33.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_34.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_35.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_36.npy",
    # "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_37.npy"
]



# Y_files = [
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_1.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_2.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_3.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_4.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_5.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_6.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_7.npy", # Fixed path here
#     "/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/connect4_Y_8.npy", # Fixed path here
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_9.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_10.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_11.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_12.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_13.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_14.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_15.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_16.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_17.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_18.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_19.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_20.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_21.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_22.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_23.npy",
#     # "/content/drive/MyDrive/Optimization-II Project 1/NN_2/connect4_Y_24.npy"
# ]


# Combine all X files into a single array
# X_files = ["connect4_X_1.npy", "connect4_X_2.npy", "connect4_X_3.npy"]
X = np.concatenate([np.load(file) for file in X_files], axis=0)

# # Combine all Y files into a single array
#Y_files = ["connect4_Y_1.npy", "connect4_Y_2.npy", "connect4_Y_3.npy"]
Y = np.concatenate([np.load(file) for file in Y_files], axis=0)

# # Check the shapes of the combined arrays
print("Combined X shape:", X.shape)
print("Combined Y shape:", Y.shape)
# Out:
# Combined X shape: (244977, 6, 7, 2)
# Combined Y shape: (244977,)

# %%
from collections import defaultdict

def consolidate_duplicates(X, Y):
    move_counts = defaultdict(lambda: defaultdict(int))

    # Count occurrences of Y for each unique X
    for x, y in zip(X, Y):
        x_key = tuple(map(tuple, x.reshape(-1, x.shape[-1])))  # Convert to hashable key
        move_counts[x_key][y] += 1

    # Select the most frequent Y for each X
    consolidated_data = []
    for board_key, moves in move_counts.items():
        most_frequent_move = max(moves, key=moves.get)
        consolidated_data.append((np.array(board_key).reshape(X.shape[1:]), most_frequent_move))

    # Convert to numpy arrays
    consolidated_X = np.array([item[0] for item in consolidated_data])
    consolidated_Y = np.array([item[1] for item in consolidated_data])
    return consolidated_X, consolidated_Y

# Apply the function to the current X and Y
consolidated_X, consolidated_Y = consolidate_duplicates(X, Y)

# Check the shapes of the combined arrays
print("Combined X shape:", consolidated_X.shape)
print("Combined Y shape:", consolidated_Y.shape)
# Out:
# Combined X shape: (238395, 6, 7, 2)
# Combined Y shape: (238395,)

# %%
def combine_with_mirrored_dataset(X, Y):
    mirrored_X = []
    mirrored_Y = []

    for x, y in zip(X, Y):
        # Create the mirror image of the board
        mirrored_board = np.flip(x, axis=1)  # Flip horizontally (mirror image)
        mirrored_X.append(mirrored_board)

        # Update the column index for the mirrored board
        mirrored_column = X.shape[2] - 1 - y  # New column index after mirroring
        mirrored_Y.append(mirrored_column)

    # Convert mirrored data to numpy arrays
    mirrored_X = np.array(mirrored_X)
    mirrored_Y = np.array(mirrored_Y)

    # Combine original and mirrored data
    combined_X = np.concatenate((X, mirrored_X), axis=0)
    combined_Y = np.concatenate((Y, mirrored_Y), axis=0)

    return combined_X, combined_Y

# Apply the function to combine the original and mirrored dataset
combined_X, combined_Y = combine_with_mirrored_dataset(consolidated_X, consolidated_Y)

# Check the shapes of the combined dataset
print("Combined X shape:", combined_X.shape)
print("Combined Y shape:", combined_Y.shape)

# Save the combined dataset if needed
np.save('/content/drive/MyDrive/Spring/Optimization-II/combined_X.npy', combined_X)
np.save('/content/drive/MyDrive/Spring/Optimization-II/combined_Y.npy', combined_Y)
# Out:
# Combined X shape: (476790, 6, 7, 2)
# Combined Y shape: (476790,)

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, regularizers

import numpy as np

# %%
np.save('/content/drive/MyDrive/Spring/Optimization-II/Project 1/combined_X.npy', combined_X)a
np.save('/content/drive/MyDrive/Spring/Optimization-II/Project 1/combined_Y.npy', combined_Y)

# %%
combined_X = np.load("/content/drive/MyDrive/Spring/Optimization-II/combined_X.npy")
combined_Y = np.load("/content/drive/MyDrive/Spring/Optimization-II/combined_Y.npy")
print("Combined X shape:", combined_X.shape)
print("Combined Y shape:", combined_Y.shape)
# Out:
# Combined X shape: (476790, 6, 7, 2)
# Combined Y shape: (476790,)

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# from tensorflow.keras.regularizers import l2



# # Ensure all moves are for 'plus' player by flipping boards if necessary
# def preprocess_board(board, move, player):
#     if player == 'minus':
#         board = np.flip(board, axis=-1)  # Swap the last dimension
#         move = 6 - move  # Mirror the move for the column
#     return board, move

# # Preprocess the dataset
# X_processed = []
# Y_processed = []
# for board, move in zip(X, Y):
#     board, move = preprocess_board(board, move, 'plus')  # Convert to 'plus'
#     X_processed.append(board)
#     Y_processed.append(move)

# X_processed = np.array(X_processed)
# Y_processed = np.array(Y_processed)

# # Split into training and validation sets
# X_train, X_val, Y_train, Y_val = train_test_split(X_processed, Y_processed, test_size=0.2, random_state=42)

# # Normalize inputs (optional, since values are binary)
# X_train = X_train.astype('float32')
# X_val = X_val.astype('float32')

# # One-hot encode the target variable
# Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=7)
# Y_val = tf.keras.utils.to_categorical(Y_val, num_classes=7)

# print('X_train Shape:', X_train.shape)

# # CNN Model
# def create_cnn():
#   model = Sequential([

#           Conv2D(64, kernel_size=(3,3), activation='relu', input_shape=(6, 7, 2), padding='same'),
#           Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'),
#           Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'),

#           Flatten(),
#           Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
#           Dropout(0.3),
#           Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
#           Dense(7, activation='softmax')  # 7 possible moves (columns)
#       ])
#   model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#   return model

# cnn_model = create_cnn()
# cnn_model.summary()

# # Train CNN
# cnn_history = cnn_model.fit(
#     X_train, Y_train,
#     validation_data=(X_val, Y_val),
#     epochs=15,
#     batch_size=32,
#     verbose=1
# )

# # # Transformer Model
# # def create_transformer():
# #     input_layer = layers.Input(shape=(6, 7, 2))
# #     reshaped = layers.Reshape((6 * 7, 2))(input_layer)  # Flatten spatial dimensions into a sequence

# #     # Transformer Encoder
# #     x = layers.MultiHeadAttention(num_heads=4, key_dim=16)(reshaped, reshaped)
# #     x = layers.LayerNormalization(epsilon=1e-6)(x)
# #     x = layers.Dense(64, activation='relu')(x)
# #     x = layers.LayerNormalization(epsilon=1e-6)(x)

# #     # Classification head
# #     x = layers.Flatten()(x)
# #     x = layers.Dense(128, activation='relu')(x)
# #     x = layers.Dropout(0.3)(x)
# #     output_layer = layers.Dense(7, activation='softmax')(x)  # 7 possible moves

# #     model = models.Model(inputs=input_layer, outputs=output_layer)
# #     model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# #     return model

# # transformer_model = create_transformer()
# # transformer_model.summary()

# # # Train Transformer
# # transformer_history = transformer_model.fit(
# #     X_train, Y_train,
# #     validation_data=(X_val, Y_val),
# #     epochs=20,
# #     batch_size=32,
# #     verbose=1
# # )

# # Save the models
# # cnn_model.save("cnn_connect4.h5")
# # transformer_model.save("transformer_connect4.h5")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam



# Ensure all moves are for 'plus' player by flipping boards if necessary
def preprocess_board(board, move, player):
    if player == 'minus':
        board = np.flip(board, axis=-1)  # Swap the last dimension
        move = 6 - move  # Mirror the move for the column
    return board, move

# Preprocess the dataset
X_processed = []
Y_processed = []
for board, move in zip(combined_X, combined_Y):
    board, move = preprocess_board(board, move, 'plus')  # Convert to 'plus'
    X_processed.append(board)
    Y_processed.append(move)

X_processed = np.array(X_processed)
Y_processed = np.array(Y_processed)

# Split into training and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X_processed, Y_processed, test_size=0.2, random_state=42)

# Normalize inputs (optional, since values are binary)
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')

# One-hot encode the target variable
Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=7)
Y_val = tf.keras.utils.to_categorical(Y_val, num_classes=7)

print('X_train Shape:', X_train.shape)

# CNN Model
# def create_cnn():
#   model = Sequential([

#           Conv2D(64, kernel_size=(3,3), activation='relu', input_shape=(6, 7, 2), padding='same'),
#           Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'),
#           Conv2D(64, kernel_size=(3,3), activation='relu', padding='same'),

#           Flatten(),
#           Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
#           Dropout(0.3),
#           Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
#           Dense(7, activation='softmax')  # 7 possible moves (columns)
#       ])
#   model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#   return model

def create_cnn():
    model = Sequential([
        Conv2D(128, kernel_size=(4,4), activation='relu', input_shape=(6, 7, 2), padding='same'),
        BatchNormalization(),
        Conv2D(128, kernel_size=(4,4), activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, kernel_size=(4,4), activation='relu', padding='same'),
        BatchNormalization(),
        Flatten(),
        Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
        Dropout(0.5),
        Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
        Dropout(0.5),
        Dense(7, activation='softmax')  # Output layer
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model




cnn_model = create_cnn()
cnn_model.summary()

# Train CNN
# cnn_history = cnn_model.fit(
#     X_train, Y_train,
#     validation_data=(X_val, Y_val),
#     epochs=100,
#     batch_size=32,
#     verbose=1
# )



from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
cnn_history = cnn_model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=50,
    batch_size=128,
    callbacks=[reduce_lr],
    verbose=1
)

# final_model_path = '/content/drive/MyDrive/Spring/Optimization-II/Project 1/NN_2/CNN_final.pt'
# torch.save(model.state_dict(), final_model_path)
# print(f"Final model saved successfully at: {final_model_path}")
# Out:
# X_train Shape: (1487464, 6, 7, 2)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 6, 7, 128)           │           4,224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 6, 7, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 6, 7, 128)           │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
cnn_model.save('cnn_connect4.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Ensure all moves are for 'plus' player by flipping boards if necessary
def preprocess_board(board, move, player):
    if player == 'minus':
        board = np.flip(board, axis=-1)  # Swap the last dimension
        move = 6 - move  # Mirror the move for the column
    return board, move

# Preprocess the dataset
X_processed = []
Y_processed = []
for board, move in zip(combined_X, combined_Y):
    board, move = preprocess_board(board, move, 'plus')  # Convert to 'plus'
    X_processed.append(board)
    Y_processed.append(move)

X_processed = np.array(X_processed)
Y_processed = np.array(Y_processed)

# Split into training and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X_processed, Y_processed, test_size=0.2, random_state=42)

# Normalize inputs (optional, since values are binary)
X_train = X_train.astype('float32')
X_val = X_val.astype('float32')

# One-hot encode the target variable
Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=7)
Y_val = tf.keras.utils.to_categorical(Y_val, num_classes=7)

print('X_train Shape:', X_train.shape)
# Out:
# X_train Shape: (381432, 6, 7, 2)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Embedding, Dense

class LearnablePositionalEncoding(Layer):
    def __init__(self, seq_length, embed_dim):
        super(LearnablePositionalEncoding, self).__init__()
        self.pos_embedding = Embedding(input_dim=seq_length, output_dim=embed_dim)

    def call(self, inputs):
        batch_size, seq_length, embed_dim = tf.shape(inputs)[0], tf.shape(inputs)[1], tf.shape(inputs)[2]
        position_indices = tf.range(seq_length)  # Generate position indices
        position_embeddings = self.pos_embedding(position_indices)  # Get embeddings

        # ✅ Ensure same shape before addition
        position_embeddings = tf.expand_dims(position_embeddings, axis=0)  # Shape: [1, seq_length, embed_dim]
        position_embeddings = tf.tile(position_embeddings, [batch_size, 1, 1])  # Match batch size

        return inputs + position_embeddings  # Element-wise addition


# ✅ Transformer Block with Improved Regularization
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, dropout_rate=0.2):
        super().__init__()
        self.attention = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation="relu"),
            layers.Dense(embed_dim),
        ])
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(dropout_rate)
        self.dropout2 = layers.Dropout(dropout_rate)

    def call(self, inputs, training=False):
        attn_output = self.attention(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.norm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.norm2(out1 + ffn_output)

# %%
def create_transformer_model(input_shape=(6, 7, 2), num_classes=7, embed_dim=128, num_heads=4, ff_dim=256, num_blocks=3):
    inputs = tf.keras.Input(shape=input_shape)

    # ✅ Reshape input to [batch_size, sequence_length, 2]
    x = tf.keras.layers.Reshape((input_shape[0] * input_shape[1], input_shape[2]))(inputs)

    # ✅ Project input from 2 channels → embed_dim (e.g., 128)
    x = tf.keras.layers.Dense(embed_dim)(x)

    # ✅ Apply Learnable Positional Encoding
    x = LearnablePositionalEncoding(seq_length=input_shape[0] * input_shape[1], embed_dim=embed_dim)(x)

    # ✅ Apply Transformer Blocks
    for _ in range(num_blocks):
        x = TransformerBlock(embed_dim, num_heads, ff_dim, dropout_rate=0.2)(x, training=True)

    # ✅ Pooling & Output Layer
    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)

    # ✅ Build Model
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
transformer_model = create_transformer_model()

# ✅ Compile Model - Use categorical_crossentropy
transformer_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                          loss="categorical_crossentropy",  # Changed to categorical_crossentropy
                          metrics=["accuracy"])

# %%
# ✅ Callbacks for Optimization
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

# ✅ Train Model
history = transformer_model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=35,
    batch_size=64,  # Try 128 if memory allows
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/35
# 5960/5960 ━━━━━━━━━━━━━━━━━━━━ 149s 21ms/step - accuracy: 0.2862 - loss: 1.6735 - val_accuracy: 0.3530 - val_loss: 1.5467
# Epoch 2/35
# 5960/5960 ━━━━━━━━━━━━━━━━━━━━ 121s 19ms/step - accuracy: 0.3520 - loss: 1.5513 - val_accuracy: 0.3672 - val_loss: 1.5267
# Epoch 3/35
# 5960/5960 ━━━━━━━━━━━━━━━━━━━━ 113s 19ms/step - accuracy: 0.3669 - loss: 1.5286 - val_accuracy: 0.3768 - val_loss: 1.5089
# Epoch 4/35
# 5960/5960 ━━━━━━━━━━━━━━━━━━━━ 114s 19ms/step - accuracy: 0.3833 - loss: 1.5021 - val_accuracy: 0.3960 - val_loss: 1.4887
# Epoch 5/35
# 5960/5960 ━━━━━━━━━━━━━━━━━━━━ 142s 19ms/step - accuracy: 0.4032 - loss: 1.4685 - val_accuracy: 0.4197 - val_loss: 1.4480
# Epoch 6/35
# 5960/5960 ━━━━━━━━━━━━━━━━━━━━ 142s 19ms/step - accuracy: 0.4214 - loss: 1.4399 - val_accuracy: 0.4292 - val_loss: 1.4211
# Epoch 7/35
# 5960/5960 ━━━━━━━━━━━━━━━━━━━━ 142s 19ms/step - accuracy: 0.4283 - loss: 1.4219 - val_accuracy: 0.4285 - val_loss: 1.4210
# Epoch 8/35
# ...

# %%
transformer_model.save('/content/drive/MyDrive/Spring/Optimization-II/Project 1/myconnect4_transformer_model_lessdata_new.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
transformer_model.save('/content/drive/MyDrive/Spring/Optimization-II/Project 1/myconnect4_transformer_model.keras')

# %%
transformer_model.export('/content/drive/MyDrive/Spring/Optimization-II/Project 1/tf_standard_format_myconnect4_transformer_model')
# Out:
# Saved artifact at '/content/drive/MyDrive/Spring/Optimization-II/Project 1/tf_standard_format_myconnect4_transformer_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 6, 7, 2), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   134958420253136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134958420254672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134958420253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134958420258512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134958420257744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134958420260240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134958420260048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134958420260624: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
